# %% [markdown]
# <a href="https://colab.research.google.com/github/evyathar/HTML_WEB/blob/main/myfirstcolabnotebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
print(time.ctime())
# Out:
# Sun Oct 26 09:46:53 2025

# %%
time.sleep(5)
print (time.ctime())
# Out:
# Sun Oct 26 09:48:59 2025
